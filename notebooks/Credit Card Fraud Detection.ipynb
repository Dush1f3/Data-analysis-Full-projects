# %%
import pandas as pd

# Load the dataset
df = pd.read_csv(r"D:\code\data\projects\full projects\fraud-detection-project\data\creditcard.csv")

# Display first few rows
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Check dataset shape and types
df.info()

# Summary statistics
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# Check for nulls
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Value counts of fraud vs. non-fraud
df['Class'].value_counts()

# Percentage distribution
fraud_percentage = df['Class'].value_counts(normalize=True) * 100
print(fraud_percentage)
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Plot class distribution
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Class' , hue = 'Class' , palette = 'coolwarm' , legend=False)
plt.title('Transaction Class Distribution (0 = Legit, 1 = Fraud)')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()
plt.savefig('fraud_distribution.png', dpi=300, bbox_inches='tight')  # High-resolution PNG
plt.show()

# %%
# Histogram of Amount for all transactions
plt.figure(figsize=(6,4))
sns.histplot(df['Amount'], bins=50, kde=True)
plt.title('Distribution of Transaction Amounts')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()

# %%
# Compare distribution of Amount for fraud vs. non-fraud
plt.figure(figsize=(8,4))
sns.boxplot(data=df, x='Class', y='Amount', color='skyblue')
plt.title('Amount Comparison by Class')
plt.xlabel('Class')
plt.ylabel('Transaction Amount')
plt.yscale('log')  # Optional: scale for better visibility
plt.show()

# %%
# Correlation matrix
corr = df.corr()

# Plot heatmap
plt.figure(figsize=(16,10))
sns.heatmap(corr, cmap='coolwarm_r', annot=False, linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# Time vs Class
plt.figure(figsize=(10,4))
sns.histplot(data=df, x='Time', hue='Class', bins=100, element="step", palette="coolwarm")
plt.title('Distribution of Transactions Over Time')
plt.xlabel('Time (seconds since first transaction)')
plt.ylabel('Count')
plt.show()

# %%
# **Data Preprocessing and Balancing (SMOTE)**

# %%
from sklearn.preprocessing import StandardScaler

# Create copies to preserve original
df_scaled = df.copy()

# Standard scaling on 'Amount' and 'Time'
scaler = StandardScaler()
df_scaled[['Amount', 'Time']] = scaler.fit_transform(df_scaled[['Amount', 'Time']])

# %%
# Define features and target
X = df_scaled.drop('Class', axis=1)
y = df_scaled['Class']

# %%
from sklearn.model_selection import train_test_split

# Stratified split to preserve fraud distribution
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# Confirm new class distribution
print(pd.Series(y_train_balanced).value_counts())
# Out:
# C:\Users\dushy\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Class
# 0    227451
# 1    227451
# Name: count, dtype: int64

# %%
print(pd.Series(y_train_balanced).value_counts())
# Out:
# Class
# 0    227451
# 1    227451
# Name: count, dtype: int64

# %%
##Model Training and Evaluation

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
import seaborn as sns
import matplotlib.pyplot as plt

def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1]

    print(classification_report(y_test, y_pred, digits=4))
    print("ROC-AUC Score:", roc_auc_score(y_test, y_proba))

    # Confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

    # ROC Curve
    fpr, tpr, _ = roc_curve(y_test, y_proba)
    plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc_score(y_test, y_proba):.4f})')
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend()
    plt.show()

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train_balanced, y_train_balanced)

print("📊 Logistic Regression Performance:")
evaluate_model(log_reg, X_test, y_test)
# Out:
# 📊 Logistic Regression Performance:
#               precision    recall  f1-score   support
#
#            0     0.9999    0.9744    0.9869     56864
#            1     0.0581    0.9184    0.1094        98
#
#     accuracy                         0.9743     56962
#    macro avg     0.5290    0.9464    0.5481     56962
# weighted avg     0.9982    0.9743    0.9854     56962
#
# ROC-AUC Score: 0.9698482164390798

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train_balanced, y_train_balanced)

print("📊 Random Forest Performance:")
evaluate_model(rf, X_test, y_test)
# Out:
# 📊 Random Forest Performance:
#               precision    recall  f1-score   support
#
#            0     0.9997    0.9997    0.9997     56864
#            1     0.8454    0.8367    0.8410        98
#
#     accuracy                         0.9995     56962
#    macro avg     0.9225    0.9182    0.9204     56962
# weighted avg     0.9995    0.9995    0.9995     56962
#
# ROC-AUC Score: 0.973103297664029

# %%
# !pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(random_state=42)
xgb.fit(X_resampled, y_resampled)

# Now save the model
import joblib
joblib.dump(xgb, 'xgboost_fraud_model.pkl')
# Out:
# ['xgboost_fraud_model.pkl']

# %%
pip install shap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/545.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/545.2 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/545.2 kB ? eta -:--:--
#    -------------------------------------- 545.2/545.2 kB 754.9 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import shap

# %%
# Initialize TreeExplainer
explainer = shap.Explainer(xgb)

# Get SHAP values for the test set
shap_values = explainer(X_test)

# Summary plot (feature importance)
shap.summary_plot(shap_values, X_test)

# %%
# Select one index (e.g., 10th row)
shap.plots.waterfall(shap_values[10])

# %%
shap.initjs()

# Make sure shap_values is an Explanation object
shap_values = explainer(X_test)

# This works!
shap.force_plot(shap_values[10].base_values, shap_values[10].values, shap_values[10].data)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %% [markdown]
# joblib.dump(scaler, 'standard_scaler.pkl')
